# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Abinay Rachakonda\Downloads\archive (3)\ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.shape
# Out:
# (607, 12)

# %% [markdown]
# # Data cleaning

# %%
df.pop('Unnamed: 0')
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 602    602
# 603    603
# 604    604
# 605    605
# 606    606
# Name: Unnamed: 0, Length: 607, dtype: int64

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (607, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# # non_visual analysis

# %%
discrete_df = df.select_dtypes(include=['object'])

# %%
def discrete_univariate_analysis(discrete_data):
  for col_name in discrete_data:
    print("*"*10, col_name, "*"*10)
    print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', discrete_data[col_name].value_counts())
    print()

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** experience_level **********
# count                   607
# nunique                   4
# unique     [MI, SE, EN, EX]
# Name: experience_level, dtype: object
# Value Counts:
#  SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64
#
# ********** employment_type **********
# count                   607
# nunique                   4
# unique     [FT, CT, PT, FL]
# Name: employment_type, dtype: object
# Value Counts:
#  FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64
#
# ********** job_title **********
# count                                                    607
# nunique                                                   50
# unique     [Data Scientist, Machine Learning Scientist, B...
# Name: job_title, dtype: object
# Value Counts:
#  Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# ...

# %%
discrete_df = df.select_dtypes(include=['object'])

# %%
def discrete_univariate_analysis(discrete_data):
  for col_name in discrete_data:
    print("*"*10, col_name, "*"*10)
    print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', discrete_data[col_name].value_counts())
    print()

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** experience_level **********
# count                   607
# nunique                   4
# unique     [MI, SE, EN, EX]
# Name: experience_level, dtype: object
# Value Counts:
#  SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64
#
# ********** employment_type **********
# count                   607
# nunique                   4
# unique     [FT, CT, PT, FL]
# Name: employment_type, dtype: object
# Value Counts:
#  FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64
#
# ********** job_title **********
# count                                                    607
# nunique                                                   50
# unique     [Data Scientist, Machine Learning Scientist, B...
# Name: job_title, dtype: object
# Value Counts:
#  Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# ...

# %% [markdown]
# # univarite analysis

# %%
sns.countplot(data=df,x='experience_level')
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='count'>

# %%
sns.countplot(data=df,x='company_size')
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='count'>

# %%
sns.countplot(data=df,x='work_year')
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='count'>

# %% [markdown]
# # Bivarite analysis

# %%
sns.pairplot(df, hue = 'job_title')

# %%
fig, axs = plt.subplots( figsize=(10,10), layout="constrained")
fig.suptitle("boxen plot")
sns.boxenplot(data=df,y='job_title',x='salary')
plt.show()

# %%
fig, axs = plt.subplots( figsize=(5,5), layout="constrained")
fig.suptitle("bar plot")
sns.barplot(data=df,x='experience_level',y='salary')
plt.show()

# %%
fig, axs = plt.subplots( figsize=(5,5), layout="constrained")
fig.suptitle("bar plot")
sns.barplot(data=df,x='company_size',y='salary')
plt.show()

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
fig, axs = plt.subplots( figsize=(5,5), layout="constrained")
fig.suptitle("bar plot")
sns.scatterplot(data=df,x='employment_type',y='salary')
plt.show()

# %%
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(),annot=True,linewidths=1.8)
# Out:
# <AxesSubplot:>
